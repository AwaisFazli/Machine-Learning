# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import DBSCAN
from sklearn import datasets
from sklearn.neighbors import NearestNeighbors

# %%
x, y = datasets.make_moons(n_samples= 2500, noise= 0.05)

# %%
x1 = x[:, 0]
x2 = x[:, 1]

# %%
x = np.array(x)
x.shape
# Out:
# (2500, 2)

# %%
plt.scatter(x1,x2, s=5)

# %%
neigh = NearestNeighbors(n_neighbors=3)
nbrs = neigh.fit(x)
distance , indices = nbrs.kneighbors(x)

# %%
distance = np.sort(distance, axis=0)
distance = distance[:,1]
plt.plot(distance)

# %%
distance
# Out:
# array([0.00016256, 0.00016256, 0.00016793, ..., 0.0967761 , 0.09944535,
#        0.10322331])

# %%
model = DBSCAN(eps=0.10)
model.fit(x)
# Out:
# DBSCAN(algorithm='auto', eps=0.1, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=5, n_jobs=None, p=None)

# %%
y_pred = model.labels_.astype(np.int)
y_pred
# Out:
# array([0, 1, 1, ..., 1, 1, 1])

# %%
colors = np.array(['#000000','#A9A9A9'])
plt.scatter(x1, x2, s= 5, color = colors[y_pred])
