# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler
from sklearn import tree

# %%
df = pd.read_csv("/content/drive/MyDrive/Collab DataSets/Position_Salaries.csv")
df.head()
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
x = df.iloc[:, 1:2].values
y = df.iloc[:, 2:3].values

# %%
x_train , x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
# sc= StandardScaler()
# x_train = sc.fit_transform(x_train)
# x_test = sc.transform(x_test)

# y_train = sc.fit_transform(y_train)
# y_test = sc.fit_transform(y_test)

# %%
modelDT = DecisionTreeRegressor(random_state= 0)
modelDT.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %%
plt.figure(figsize=(15, 10))
tree.plot_tree(modelDT, filled= True)
# Out:
# [Text(592.875, 498.3, 'X[0] <= 9.0\nmse = 88437109375.0\nsamples = 8\nvalue = 241875.0'),
#  Text(523.125, 407.70000000000005, 'X[0] <= 6.5\nmse = 7233673469.388\nsamples = 7\nvalue = 133571.429'),
#  Text(348.75, 317.1, 'X[0] <= 4.5\nmse = 1536000000.0\nsamples = 5\nvalue = 87000.0'),
#  Text(209.25, 226.5, 'X[0] <= 3.0\nmse = 238888888.889\nsamples = 3\nvalue = 58333.333'),
#  Text(139.5, 135.89999999999998, 'X[0] <= 1.5\nmse = 6250000.0\nsamples = 2\nvalue = 47500.0'),
#  Text(69.75, 45.299999999999955, 'mse = 0.0\nsamples = 1\nvalue = 45000.0'),
#  Text(209.25, 45.299999999999955, 'mse = 0.0\nsamples = 1\nvalue = 50000.0'),
#  Text(279.0, 135.89999999999998, 'mse = 0.0\nsamples = 1\nvalue = 80000.0'),
#  Text(488.25, 226.5, 'X[0] <= 5.5\nmse = 400000000.0\nsamples = 2\nvalue = 130000.0'),
#  Text(418.5, 135.89999999999998, 'mse = 0.0\nsamples = 1\nvalue = 110000.0'),
#  Text(558.0, 135.89999999999998, 'mse = 0.0\nsamples = 1\nvalue = 150000.0'),
#  Text(697.5, 317.1, 'X[0] <= 7.5\nmse = 2500000000.0\nsamples = 2\nvalue = 250000.0'),
#  Text(627.75, 226.5, 'mse = 0.0\nsamples = 1\nvalue = 200000.0'),
#  Text(767.25, 226.5, 'mse = 0.0\nsamples = 1\nvalue = 300000.0'),
#  Text(662.625, 407.70000000000005, 'mse = 0.0\nsamples = 1\nvalue = 1000000.0')]

# %%
y_pred = modelDT.predict([[6.5]])
y_pred
# Out:
# array([150000.])

# %%
mse = mean_squared_error(y_test, modelDT.predict(x_test))
print(f"The Mean Squared Error Of Model is {math.sqrt(mse)}")
print(f"And Squared Value Is {modelDT.score(x,y)}")
# Out:
# The Mean Squared Error Of Model is 141598.02258506295
# And Squared Value Is 0.9502865342833854

# %%
plt.scatter(x, y)
plt.plot(x, modelDT.predict(x))
